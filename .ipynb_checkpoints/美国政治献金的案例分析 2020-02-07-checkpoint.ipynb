# %%
import pandas as pd
import numpy as np
from pandas import DataFrame,Series

# %%
df=pd.read_csv(r'D:\notebook\data20200206\contb_02.csv')
df.head()
# Out:
#          cand_nm            contbr_nm contbr_st  \
# 0  Obama, Barack  THOMAS, MAMIE ETHEL        NY
# 1  Obama, Barack         PIZZI, JULIA        NY
# 2  Obama, Barack        LEHRER, RANDY        NY
# 3  Obama, Barack     MARKS, ELIZABETH        NY
# 4  Obama, Barack         GELB, DANIEL        NY
#
#                   contbr_employer     contbr_occupation  contb_receipt_amt  \
# 0                         RETIRED               RETIRED              200.0
# 1                 DEWEY & LEBOEUF              ATTORNEY              100.0
# 2                   SELF-EMPLOYED       PSYCHOTHERAPIST               10.0
# 3           MATTHEW MARKS GALLERY  DIRECTOR ART GALLERY              150.0
# 4  SOUTH BEACH PSYCHIATRIC CENTER         SOCIAL WORKER              150.0
#
#   contb_receipt_dt
# 0        30-SEP-11
# 1        14-SEP-11
# 2        04-JUL-11
# 3        30-SEP-11
# 4        04-AUG-11

# %%
df2=pd.read_csv(r'D:\notebook\data20200206\contb_01.csv')
df2.head()
# Out:
#               cand_nm           contbr_nm contbr_st        contbr_employer  \
# 0  Bachmann, Michelle     HARVEY, WILLIAM        AL                RETIRED
# 1  Bachmann, Michelle     HARVEY, WILLIAM        AL                RETIRED
# 2  Bachmann, Michelle       SMITH, LANIER        AL  INFORMATION REQUESTED
# 3  Bachmann, Michelle    BLEVINS, DARONDA        AR                   NONE
# 4  Bachmann, Michelle  WARDENBURG, HAROLD        AR                   NONE
#
#        contbr_occupation  contb_receipt_amt contb_receipt_dt
# 0                RETIRED              250.0        20-JUN-11
# 1                RETIRED               50.0        23-JUN-11
# 2  INFORMATION REQUESTED              250.0        05-JUL-11
# 3                RETIRED              250.0        01-AUG-11
# 4                RETIRED              300.0        20-JUN-11

# %%
df3=pd.read_csv(r'D:\notebook\data20200206\contb_03.csv')
df3
# Out:
#           cand_nm                     contbr_nm contbr_st  \
# 0     Perry, Rick                 NORRIS, BOBBY        TX
# 1     Perry, Rick                HUNT, CAROLINE        TX
# 2     Perry, Rick              ROBINOWITZ, DALE        TX
# 3     Perry, Rick        ZUNIGA, DAVID & SYLVIA        TX
# 4     Perry, Rick                FOSTER, GLENNA        TX
# 5     Perry, Rick               BAYDERE, GOKHAN        TX
# 6     Perry, Rick                 GRAHAM, JAMES        TX
# 7     Perry, Rick                   WEBB, KEITH        TX
# 8     Perry, Rick                 YUKSEL, KERIM        TX
# 9     Perry, Rick           OZGUN, MEHMET TAMER        TX
# 10    Perry, Rick                 BAYHAN, NIHAT        TX
# 11    Perry, Rick                YUKSEL, RAZIYE        TX
# 12    Perry, Rick               JONES, REGINALD        TX
# 13    Perry, Rick                HAVRAN, ROBERT        TX
# 14    Perry, Rick                 BAYHAN, SIBEL        TX
# 15    Perry, Rick                   TATUM, MARK        TX
# 16    Perry, Rick                 TATUM, TERRIE        TX
# 17    Perry, Rick          WALTER, JAMES L. MR.        TX
# 12                                   RETIRED
# 13                      TEXAS BANC. MORTGAGE
# 14                   HARMONY SCIENCE ACADAMY
# 15                GENESCO SPORTS ENTERPRISES
# 16                               LUBBOCK ISD
# 17                          FOURDERS CAPITAL
# 18                                   RETIRED
# 19                   SUNSET MEMORIAL GARDENS
# 20                ALLIANCE RENTAL CENTERS LP
# 21    INFORMATION REQUESTED PER BEST EFFORTS
# 22                          COATS & EVANS PC
# 23                CONN GROUP CONSULTING INC.
# 24                                   RETIRED
# 25                 E. & T. PLASTICS OF TEXAS
# 26                         PERRY RESTAURANTS
# 27                                   CMS USA
# 28    INFORMATION REQUESTED PER BEST EFFORTS
# 29                        LEWIS ENERGY GROUP
# ...                                      ...
# 1701                               HOMEMAKER
# 1702               PHILLIPS MACHINE SERVICES
# 1703                      SWANSON INDUSTRIES
# 1704               PHILLIPS MACHINE SERVICES
# 1705  INFORMATION REQUESTED PER BEST EFFORTS
# 1706  INFORMATION REQUESTED PER BEST EFFORTS
# 1707                   DAVID STANLEY COMPANY
# 1708  INFORMATION REQUESTED PER BEST EFFORTS
# 1709                   DAVID STANLEY COMPANY
# 1710                                     NaN
# 1711                             FRIESS INC.
# 1712              FAMILY PRACTICE ASSOCIATES
# 1713                           SELF-EMPLOYED
# 1714  INFORMATION REQUESTED PER BEST EFFORTS
# 1715                                     NaN
# 1716                                 RETIRED
# 1717                                     NaN
# 1718                                   SIRVA
# 1719                        LUCAS PROPERTIES
# 1720                                     NaN
# 1721                        TEXAS ENERGY LLC
# 1722                                     NaN
# 1723                                     NaN
# 1724  INFORMATION REQUESTED PER BEST EFFORTS
# 1725                                 AM COAL
# 1726  INFORMATION REQUESTED PER BEST EFFORTS
# 1727            DUFFY EQUIPMENT COMPANY INC.
# 1728  INFORMATION REQUESTED PER BEST EFFORTS
# 1729                                T.A.C.C.
# 1730  INFORMATION REQUESTED PER BEST EFFORTS
#
#                            contbr_occupation  contb_receipt_amt  \
# 0                           REALTOR/ RANCHER             1000.0
# 1                                  HOMEMAKER             2500.0
# 2                                    DENTIST             2500.0
# 3                                      OWNER              250.0
# 4                       INVESTOR/ CONSULTANT             1500.0
# 5                        MECHANICAL ENGINEER             2500.0
# 6                                  EXECUTIVE              500.0
# 7                                   ATTORNEY              500.0
# 8                       CONSTRUCTION MANAGER             2500.0
# 9                     SENIOR DESIGN ENGINEER             2500.0
# 10                       AREA SUPERINTENDENT             2500.0
# 11                                       NaN             2500.0
# 12                                   RETIRED              500.0
# 13                                 PRESIDENT             1000.0
# 14                                   TEACHER             2500.0
# 15                           GENERAL MANAGER             2500.0
# 16                                   TEACHER             2500.0
# 17                               INVESTMENTS              250.0
# 18                                   RETIRED              200.0
# 19                             SALES MANAGER               50.0
# 20                                       CEO              500.0
# 21    INFORMATION REQUESTED PER BEST EFFORTS             2500.0
# 22                         AVIATION ATTORNEY            -2500.0
# 23                                CONSULTING              200.0
# 24                                   RETIRED               50.0
# 25                                     SALES             2000.0
# 26                                     OWNER             2500.0
# 27                                     OWNER             2500.0
# 28    INFORMATION REQUESTED PER BEST EFFORTS             2500.0
# 29                           PRESIDENT & CEO             2500.0
# ...                                      ...                ...
# 1701                               HOMEMAKER             2500.0
# 1702                               EXECUTIVE             2500.0
# 1703                                  C.F.O.            -2500.0
# 1704                               EXECUTIVE            -2500.0
# 1705  INFORMATION REQUESTED PER BEST EFFORTS             1000.0
# 1706  INFORMATION REQUESTED PER BEST EFFORTS             2500.0
# 1707                                   SALES            -2500.0
# 1708  INFORMATION REQUESTED PER BEST EFFORTS             2500.0
# 1709                                   SALES            -2500.0
# 1710                                     NaN            -2500.0
# 1711                              CONSULTANT             1000.0
# 1712                                  DOCTOR             2500.0
# 1713                                INVESTOR             2500.0
# 1714  INFORMATION REQUESTED PER BEST EFFORTS              250.0
# 1715                                     NaN              250.0
# 1716                                 RETIRED             1000.0
# 1717                                 RETIRED              100.0
# 1718                                     CEO             2500.0
# 1719                                   OWNER             2500.0
# 1720                                 RETIRED              100.0
# 1721                               EXECUTIVE              250.0
# 1722                                 RETIRED              100.0
# 1723                                 RETIRED              100.0
# 1724  INFORMATION REQUESTED PER BEST EFFORTS              500.0
# 1725                                ENGINEER             2500.0
# 1726  INFORMATION REQUESTED PER BEST EFFORTS             5000.0
# 1727                          BUSINESS OWNER             2500.0
# 1728  INFORMATION REQUESTED PER BEST EFFORTS              500.0
# 1729            LONGWALL MAINTENANCE FOREMAN              500.0
# 1730  INFORMATION REQUESTED PER BEST EFFORTS             2500.0
#
#      contb_receipt_dt
# 0           14-DEC-11
# 1           14-DEC-11
# 2           14-DEC-11
# 3           14-DEC-11
# 4           14-DEC-11
# 5           14-DEC-11
# 6           14-DEC-11
# 7           14-DEC-11
# 8           14-DEC-11
# 9           14-DEC-11
# 10          14-DEC-11
# 11          14-DEC-11
# 12          14-DEC-11
# 13          14-DEC-11
# 14          14-DEC-11
# 15          15-DEC-11
# 16          15-DEC-11
# 17          24-OCT-11
# 18          15-NOV-11
# 19          15-NOV-11
# 20          15-NOV-11
# 21          01-OCT-11
# 22          01-OCT-11
# 23          15-NOV-11
# 24          15-NOV-11
# 25          15-NOV-11
# 26          15-NOV-11
# 27          15-NOV-11
# 28          15-NOV-11
# 29          15-NOV-11
# ...               ...
# 1701        01-OCT-11
# 1702        28-NOV-11
# 1703        01-OCT-11
# 1704        28-NOV-11
# 1705        17-NOV-11
# 1706        08-OCT-11
# 1707        08-OCT-11
# 1708        09-OCT-11
# 1709        09-OCT-11
# 1710        31-MAR-12
# 1711        29-SEP-11
# 1712        26-AUG-11
# 1713        26-AUG-11
# 1714        15-AUG-11
# 1715        30-SEP-11
# 1716        17-AUG-11
# 1717        12-NOV-11
# 1718        04-OCT-11
# 1719        04-OCT-11
# 1720        01-OCT-11
# 1721        15-NOV-11
# 1722        29-OCT-11
# 1723        30-NOV-11
# 1724        30-SEP-11
# 1725        30-SEP-11
# 1726        29-SEP-11
# 1727        30-SEP-11
# 1728        29-SEP-11
# 1729        30-SEP-11
# 1730        31-AUG-11
#
# [1731 rows x 7 columns]

# %% [markdown]
# 1 #查看一下数据的基本信息是否存在缺失值

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500001 entries, 0 to 500000
# Data columns (total 7 columns):
# cand_nm              500001 non-null object
# contbr_nm            500001 non-null object
# contbr_st            500001 non-null object
# contbr_employer      490448 non-null object
# contbr_occupation    495774 non-null object
# contb_receipt_amt    500001 non-null float64
# contb_receipt_dt     500001 non-null object
# dtypes: float64(1), object(6)
# memory usage: 26.7+ MB

# %% [markdown]
# #2只选取这些内容进行分析
# #cand_nm竞选人
#   #contbr_nm 献金人
#   #contbr_st 献金人州
#   #contbr_employer捐赠人所在公司
#     #contbr_occupation捐赠人职业
#     #contb_receipt_amt捐赠数额
#     #contb_receipt_dt捐赠日期

# %%
df=df[['cand_nm','contbr_nm','contbr_st','contbr_employer',
      'contbr_occupation','contb_receipt_amt','contb_receipt_dt']]
df.head()
# Out:
#          cand_nm            contbr_nm contbr_st  \
# 0  Obama, Barack  THOMAS, MAMIE ETHEL        NY
# 1  Obama, Barack         PIZZI, JULIA        NY
# 2  Obama, Barack        LEHRER, RANDY        NY
# 3  Obama, Barack     MARKS, ELIZABETH        NY
# 4  Obama, Barack         GELB, DANIEL        NY
#
#                   contbr_employer     contbr_occupation  contb_receipt_amt  \
# 0                         RETIRED               RETIRED              200.0
# 1                 DEWEY & LEBOEUF              ATTORNEY              100.0
# 2                   SELF-EMPLOYED       PSYCHOTHERAPIST               10.0
# 3           MATTHEW MARKS GALLERY  DIRECTOR ART GALLERY              150.0
# 4  SOUTH BEACH PSYCHIATRIC CENTER         SOCIAL WORKER              150.0
#
#   contb_receipt_dt
# 0        30-SEP-11
# 1        14-SEP-11
# 2        04-JUL-11
# 3        30-SEP-11
# 4        04-AUG-11

# %% [markdown]
# 3#用用统计学数据 快速描述数据类型种类describe（）

# %%
df.describe()
# Out:
#        contb_receipt_amt
# count      500001.000000
# mean          240.417336
# std           560.771601
# min         -5115.000000
# 25%            35.000000
# 50%           100.000000
# 75%           250.000000
# max         25000.000000

# %% [markdown]
# 4#因为保密原因，要把空值填充尾 NOT PROVIDED

# %%
df.fillna(value='NOT PROVIDED',inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500001 entries, 0 to 500000
# Data columns (total 7 columns):
# cand_nm              500001 non-null object
# contbr_nm            500001 non-null object
# contbr_st            500001 non-null object
# contbr_employer      500001 non-null object
# contbr_occupation    500001 non-null object
# contb_receipt_amt    500001 non-null float64
# contb_receipt_dt     500001 non-null object
# dtypes: float64(1), object(6)
# memory usage: 26.7+ MB

# %% [markdown]
# 5#异常值处理，对捐赠金额小于零的数据删除处理

# %%
df['contb_receipt_amt']<=0
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# 5         False
# 6         False
# 7         False
# 8         False
# 9         False
# 10        False
# 11        False
# 12        False
# 13        False
# 14        False
# 15        False
# 16        False
# 17        False
# 18        False
# 19        False
# 20        False
# 21        False
# 22        False
# 23        False
# 24        False
# 25        False
# 26        False
# 27        False
# 28        False
# 29        False
#           ...
# 499971    False
# 499972    False
# 499973    False
# 499974    False
# 499975    False
# 499976    False
# 499977    False
# 499978    False
# 499979    False
# 499980    False
# 499981     True
# 499982    False
# 499983    False
# 499984    False
# 499985    False
# 499986    False
# 499987    False
# 499988    False
# 499989    False
# 499990    False
# 499991    False
# 499992    False
# 499993     True
# 499994    False
# 499995    False
# 499996    False
# 499997    False
# 499998    False
# 499999    False
# 500000    False
# Name: contb_receipt_amt, Length: 500001, dtype: bool

# %%
df=df.loc[~(df['contb_receipt_amt']<=0)] #取反

# %% [markdown]
# 6#新建一列，各个候选人所在的党派

# %% [raw]
# #months = {'JAN' : 1, 'FEB' : 2, 'MAR' : 3, 'APR' : 4, 'MAY' : 5, 'JUN' : 6,
#           'JUL' : 7, 'AUG' : 8, 'SEP' : 9, 'OCT': 10, 'NOV': 11, 'DEC' : 12}
# of_interest = ['Obama, Barack', 'Romney, Mitt', 'Santorum, Rick',
#                'Paul, Ron', 'Gingrich, Newt']
# parties = {
#   'Bachmann, Michelle': 'Republican',
#   'Romney, Mitt': 'Republican',
#   'Obama, Barack': 'Democrat',
#   "Roemer, Charles E. 'Buddy' III": 'Reform',
#   'Pawlenty, Timothy': 'Republican',
#   'Johnson, Gary Earl': 'Libertarian',
#   'Paul, Ron': 'Republican',
#   'Santorum, Rick': 'Republican',
#   'Cain, Herman': 'Republican',
#   'Gingrich, Newt': 'Republican',
#   'McCotter, Thaddeus G': 'Republican',
#   'Huntsman, Jon': 'Republican',
#   'Perry, Rick': 'Republican'
#  }

# %%
#共有多少不同的候选人
df['cand_nm'].unique()
# Out:
# array(['Obama, Barack', "Roemer, Charles E. 'Buddy' III",
#        'Pawlenty, Timothy', 'Johnson, Gary Earl', 'Paul, Ron',
#        'Santorum, Rick', 'Cain, Herman', 'Gingrich, Newt',
#        'Bachmann, Michelle', 'McCotter, Thaddeus G', 'Huntsman, Jon',
#        'Perry, Rick'], dtype=object)

# %%
#用到映射
parties = {
  'Bachmann, Michelle': 'Republican',
  'Romney, Mitt': 'Republican',
  'Obama, Barack': 'Democrat',
  "Roemer, Charles E. 'Buddy' III": 'Reform',
  'Pawlenty, Timothy': 'Republican',
  'Johnson, Gary Earl': 'Libertarian',
  'Paul, Ron': 'Republican',
  'Santorum, Rick': 'Republican',
  'Cain, Herman': 'Republican',
  'Gingrich, Newt': 'Republican',
  'McCotter, Thaddeus G': 'Republican',
  'Huntsman, Jon': 'Republican',
  'Perry, Rick': 'Republican'           
 }

# %%
df['cand_nm'].map(parties)
# Out:
# 0           Democrat
# 1           Democrat
# 2           Democrat
# 3           Democrat
# 4           Democrat
# 5           Democrat
# 6           Democrat
# 7           Democrat
# 8           Democrat
# 9           Democrat
# 10          Democrat
# 11          Democrat
# 12          Democrat
# 13          Democrat
# 14          Democrat
# 15          Democrat
# 16          Democrat
# 17          Democrat
# 18          Democrat
# 19          Democrat
# 20          Democrat
# 21          Democrat
# 22          Democrat
# 23          Democrat
# 24          Democrat
# 25          Democrat
# 26          Democrat
# 27          Democrat
# 28          Democrat
# 29          Democrat
#              ...
# 499969    Republican
# 499970    Republican
# 499971    Republican
# 499972    Republican
# 499973    Republican
# 499974    Republican
# 499975    Republican
# 499976    Republican
# 499977    Republican
# 499978    Republican
# 499979    Republican
# 499980    Republican
# 499982    Republican
# 499983    Republican
# 499984    Republican
# 499985    Republican
# 499986    Republican
# 499987    Republican
# 499988    Republican
# 499989    Republican
# 499990    Republican
# 499991    Republican
# 499992    Republican
# 499994    Republican
# 499995    Republican
# 499996    Republican
# 499997    Republican
# 499998    Republican
# 499999    Republican
# 500000    Republican
# Name: cand_nm, Length: 495156, dtype: object

# %%
df['parties']=df['cand_nm'].map(parties)

# %%
df.head()
# Out:
#          cand_nm            contbr_nm contbr_st  \
# 0  Obama, Barack  THOMAS, MAMIE ETHEL        NY
# 1  Obama, Barack         PIZZI, JULIA        NY
# 2  Obama, Barack        LEHRER, RANDY        NY
# 3  Obama, Barack     MARKS, ELIZABETH        NY
# 4  Obama, Barack         GELB, DANIEL        NY
#
#                   contbr_employer     contbr_occupation  contb_receipt_amt  \
# 0                         RETIRED               RETIRED              200.0
# 1                 DEWEY & LEBOEUF              ATTORNEY              100.0
# 2                   SELF-EMPLOYED       PSYCHOTHERAPIST               10.0
# 3           MATTHEW MARKS GALLERY  DIRECTOR ART GALLERY              150.0
# 4  SOUTH BEACH PSYCHIATRIC CENTER         SOCIAL WORKER              150.0
#
#   contb_receipt_dt   parties
# 0        30-SEP-11  Democrat
# 1        14-SEP-11  Democrat
# 2        04-JUL-11  Democrat
# 3        30-SEP-11  Democrat
# 4        04-AUG-11  Democrat

# %% [markdown]
# 7#查看parties这一列中有哪些不同的元素，并统计parties中元素出现的次数

# %%
df['parties'].unique()
# Out:
# array(['Democrat', 'Reform', 'Republican', 'Libertarian'], dtype=object)

# %%
df['parties'].count() #发现不对
# Out:
# 495156

# %%
df['parties'].value_counts()  #value_counts()就是用来统计series里面不同项目的个数汇总
# Out:
# Republican     288169
# Democrat       199909
# Reform           5844
# Libertarian      1234
# Name: parties, dtype: int64

# %% [markdown]
# #8查看各个党派收到的政治献金的总数

# %%
#先用透视表来表达分组
pd.pivot_table(df,values='contb_receipt_amt',index='parties',aggfunc='sum')
# Out:
#              contb_receipt_amt
# parties
# Democrat          4.240803e+07
# Libertarian       5.669616e+05
# Reform            3.730099e+05
# Republican        8.244323e+07

# %%
#groupby的方法
df.groupby(by='parties')['contb_receipt_amt'].sum()
# Out:
# parties
# Democrat       4.240803e+07
# Libertarian    5.669616e+05
# Reform         3.730099e+05
# Republican     8.244323e+07
# Name: contb_receipt_amt, dtype: float64

# %% [markdown]
# #9查看每天每个党派收到的钱钱的总数

# %%
df.groupby(by=['contb_receipt_dt','parties'])['contb_receipt_amt'].sum()
# Out:
# contb_receipt_dt  parties
# 01-APR-11         Reform              50.00
#                   Republican       12635.00
# 01-APR-12         Democrat         65569.22
#                   Libertarian        625.00
#                   Republican       56939.32
# 01-AUG-11         Democrat         59345.00
#                   Libertarian       1000.00
#                   Reform            1847.00
#                   Republican      127621.46
# 01-DEC-11         Democrat        255241.97
#                   Libertarian        725.00
#                   Reform             875.00
#                   Republican      254524.28
# 01-FEB-11         Republican         250.00
# 01-FEB-12         Democrat        223275.74
#                   Libertarian        475.00
#                   Reform            2695.00
#                   Republican      186941.92
# 01-JAN-11         Republican        8600.00
# 01-JAN-12         Democrat         34840.98
#                  Libertarian             250.00
#                  Reform                  100.00
#                  Republican           115659.80
# 31-OCT-11        Democrat              41834.12
#                  Libertarian            4250.00
#                  Reform                 3205.00
#                  Republican           300105.93
#
# [1549 rows x 1 columns]

# %% [markdown]
# 10#将原始数据中的时间格式改成yy-mm-dd

# %%
months = {'JAN' : 1, 'FEB' : 2, 'MAR' : 3, 'APR' : 4, 'MAY' : 5, 'JUN' : 6,
          'JUL' : 7, 'AUG' : 8, 'SEP' : 9, 'OCT': 10, 'NOV': 11, 'DEC' : 12}

# %%
months['SEP']
# Out:
# 9

# %%
def transform_date(s):
    day,month,year=s.split('-')   #因为显示的数据是数字和英文，不能改变列细节的情况下只能想到拆分
    month = months[month]        #month里面是sep这些英文，带入字典会返回相应的int数字对应相应的月份
    return '20'+year+'-'+str(month)+'-'+day #因为字典里的数字是int 而初始时间序列里的数据是object，需要改格式

# %%
df['contb_receipt_dt'].map(transform_date)
# Out:
# 0          2011-9-30
# 1          2011-9-14
# 2          2011-7-04
# 3          2011-9-30
# 4          2011-8-04
# 5          2011-9-21
# 6          2011-9-26
# 7          2011-9-28
# 8          2011-8-04
# 9          2011-9-27
# 10         2011-7-25
# 11         2011-9-23
# 12         2011-9-27
# 13         2011-8-04
# 14         2011-9-07
# 15         2011-9-27
# 16         2011-8-29
# 17         2011-9-09
# 18         2011-9-08
# 19         2011-9-05
# 20         2011-9-16
# 21         2011-8-05
# 22         2011-7-26
# 23         2011-8-12
# 24         2011-7-13
# 25         2011-9-30
# 26         2011-9-16
# 27         2011-9-27
# 28         2011-8-04
# 29         2011-8-22
#              ...
# 499969    2011-12-14
# 499970    2011-12-14
# 499971    2011-12-20
# 499972    2011-12-20
# 499973    2011-12-20
# 499974    2011-12-27
# 499975    2011-11-15
# 499976    2011-11-15
# 499977    2011-11-15
# 499978    2011-12-20
# 499979    2011-12-15
# 499980    2011-12-15
# 499982    2011-12-15
# 499983    2011-12-15
# 499984    2011-12-15
# 499985    2011-12-15
# 499986    2011-12-15
# 499987    2011-12-15
# 499988    2011-12-19
# 499989    2011-12-19
# 499990    2011-12-19
# 499991    2011-12-19
# 499992    2011-12-27
# 499994    2011-12-27
# 499995    2011-12-27
# 499996    2011-12-13
# 499997    2011-12-13
# 499998    2011-12-14
# 499999    2011-12-14
# 500000    2011-12-14
# Name: contb_receipt_dt, Length: 495156, dtype: object

# %% [markdown]
# #最后将这行覆盖，就能得到具体的时间数据 用df看就行了
# #df['contb_receipt_dt']=df['contb_receipt_dt'].map(transform_date)

# %% [markdown]
# 11#查看老兵这个职业支持谁Disabled Veteran

# %%
df['contbr_occupation']=='DISABLED VETERAN'
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# 5         False
# 6         False
# 7         False
# 8         False
# 9         False
# 10        False
# 11        False
# 12        False
# 13        False
# 14        False
# 15        False
# 16        False
# 17        False
# 18        False
# 19        False
# 20        False
# 21        False
# 22        False
# 23        False
# 24        False
# 25        False
# 26        False
# 27        False
# 28        False
# 29        False
#           ...
# 499969    False
# 499970    False
# 499971    False
# 499972    False
# 499973    False
# 499974    False
# 499975    False
# 499976    False
# 499977    False
# 499978    False
# 499979    False
# 499980    False
# 499982    False
# 499983    False
# 499984    False
# 499985    False
# 499986    False
# 499987    False
# 499988    False
# 499989    False
# 499990    False
# 499991    False
# 499992    False
# 499994    False
# 499995    False
# 499996    False
# 499997    False
# 499998    False
# 499999    False
# 500000    False
# Name: contbr_occupation, Length: 495156, dtype: bool

# %%
df5=df.loc[df['contbr_occupation']=='DISABLED VETERAN']

# %%
df5.groupby(by='cand_nm').aggregate({'contb_receipt_amt':'sum'}).sort_values('contb_receipt_amt',ascending=False)
# Out:
#                                 contb_receipt_amt
# cand_nm
# Paul, Ron                                  4439.1
# Obama, Barack                              1585.0
# Santorum, Rick                              550.0
# Cain, Herman                                300.0
# Gingrich, Newt                              250.0
# Roemer, Charles E. 'Buddy' III              100.0

# %%
df5.groupby(by='cand_nm')['contb_receipt_amt'].sum()
# Out:
# cand_nm
# Cain, Herman                       300.0
# Gingrich, Newt                     250.0
# Obama, Barack                     1585.0
# Paul, Ron                         4439.1
# Roemer, Charles E. 'Buddy' III     100.0
# Santorum, Rick                     550.0
# Name: contb_receipt_amt, dtype: float64

# %% [markdown]
# #11找出各个候选人，的捐赠者捐赠金额最大的职业，以及捐赠数额

# %%
s=df.groupby(by=['cand_nm']).aggregate({'contb_receipt_amt':'max'})#选出候选人和接受献金的最大金额的合并表
s                                                               #然后塞入原表 关联一对一对应的职业从而展示
# Out:
#                                 contb_receipt_amt
# cand_nm
# Bachmann, Michelle                         5000.0
# Cain, Herman                              10000.0
# Gingrich, Newt                             5100.0
# Huntsman, Jon                              5000.0
# Johnson, Gary Earl                         2500.0
# McCotter, Thaddeus G                       4000.0
# Obama, Barack                              7000.0
# Paul, Ron                                 25000.0
# Pawlenty, Timothy                         10000.0
# Perry, Rick                               10000.0
# Roemer, Charles E. 'Buddy' III              200.0
# Santorum, Rick                            10000.0

# %%
for i in range(s.size):#s.size就是返回矩阵中元素的个数，等于是将矩阵中的数据一一遍历
    ex='cand_nm=="%s" & contb_receipt_amt==%s'%(s.index[i],s.values[i])
# cand中的值等于%s中的值且等于amt列中的相对应的值“”这里面的相对应的函数%表示就是s.index[i]
#s矩阵中的索引i遍历，因为i in range（s.size）,因为用的是同一个i所以数据是一一对应的。这样带入df的ex才能一致
#比如 in range（5）就是在 【1,2,3,4,5】中的数据，一个个取出来
    print(ex)
    #display(df.query(ex))
# Out:
# cand_nm=="Bachmann, Michelle" & contb_receipt_amt==[5000.]
# cand_nm=="Cain, Herman" & contb_receipt_amt==[10000.]
# cand_nm=="Gingrich, Newt" & contb_receipt_amt==[5100.]
# cand_nm=="Huntsman, Jon" & contb_receipt_amt==[5000.]
# cand_nm=="Johnson, Gary Earl" & contb_receipt_amt==[2500.]
# cand_nm=="McCotter, Thaddeus G" & contb_receipt_amt==[4000.]
# cand_nm=="Obama, Barack" & contb_receipt_amt==[7000.]
# cand_nm=="Paul, Ron" & contb_receipt_amt==[25000.]
# cand_nm=="Pawlenty, Timothy" & contb_receipt_amt==[10000.]
# cand_nm=="Perry, Rick" & contb_receipt_amt==[10000.]
# cand_nm=="Roemer, Charles E. 'Buddy' III" & contb_receipt_amt==[200.]
# cand_nm=="Santorum, Rick" & contb_receipt_amt==[10000.]
