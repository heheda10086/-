# %%
import pandas as pd
from pandas import Series,DataFrame
import tushare as ts
import matplotlib.pyplot as plt

# %%
df=ts.get_k_data('600519',start='1988-01-01')

# %%
df.to_csv('./maotai.csv')

# %%
df = pd.read_csv('./maotai.csv')

# %%
df.head(5)
# Out:
#    Unnamed: 0        date   open  close   high    low     volume    code
# 0           0  2001-08-27  5.392  5.554  5.902  5.132  406318.00  600519
# 1           1  2001-08-28  5.467  5.759  5.781  5.407  129647.79  600519
# 2           2  2001-08-29  5.777  5.684  5.781  5.640   53252.75  600519
# 3           3  2001-08-30  5.668  5.796  5.860  5.624   48013.06  600519
# 4           4  2001-08-31  5.804  5.782  5.877  5.749   23231.48  600519

# %%
df.drop(labels='Unnamed: 0',axis=1,inplace=True)

# %%
df.head(5)
# Out:
#          date   open  close   high    low     volume    code
# 0  2001-08-27  5.392  5.554  5.902  5.132  406318.00  600519
# 1  2001-08-28  5.467  5.759  5.781  5.407  129647.79  600519
# 2  2001-08-29  5.777  5.684  5.781  5.640   53252.75  600519
# 3  2001-08-30  5.668  5.796  5.860  5.624   48013.06  600519
# 4  2001-08-31  5.804  5.782  5.877  5.749   23231.48  600519

# %%
df.dtypes
# Out:
# date       object
# open      float64
# close     float64
# high      float64
# low       float64
# volume    float64
# code        int64
# dtype: object

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df.dtypes
# Out:
# date      datetime64[ns]
# open             float64
# close            float64
# high             float64
# low              float64
# volume           float64
# code               int64
# dtype: object

# %%
df.set_index(df['date'],inplace=True)

# %%
df.head()
# Out:
#                  date   open  close   high    low     volume    code
# date
# 2001-08-27 2001-08-27  5.392  5.554  5.902  5.132  406318.00  600519
# 2001-08-28 2001-08-28  5.467  5.759  5.781  5.407  129647.79  600519
# 2001-08-29 2001-08-29  5.777  5.684  5.781  5.640   53252.75  600519
# 2001-08-30 2001-08-30  5.668  5.796  5.860  5.624   48013.06  600519
# 2001-08-31 2001-08-31  5.804  5.782  5.877  5.749   23231.48  600519

# %%
df.drop(labels="date",axis=1,inplace=True)

# %%
df.head()
# Out:
#              open  close   high    low     volume    code
# date
# 2001-08-27  5.392  5.554  5.902  5.132  406318.00  600519
# 2001-08-28  5.467  5.759  5.781  5.407  129647.79  600519
# 2001-08-29  5.777  5.684  5.781  5.640   53252.75  600519
# 2001-08-30  5.668  5.796  5.860  5.624   48013.06  600519
# 2001-08-31  5.804  5.782  5.877  5.749   23231.48  600519

# %%
result_list = (df['close']-df['open'])/df['open']>0.03

# %%
type(result_list)
# Out:
# pandas.core.series.Series

# %%
df.loc[result_list].index
# Out:
# DatetimeIndex(['2001-08-27', '2001-08-28', '2001-09-10', '2001-12-21',
#                '2002-01-18', '2002-01-31', '2003-01-14', '2003-10-29',
#                '2004-01-05', '2004-01-14',
#                ...
#                '2019-03-01', '2019-03-18', '2019-04-10', '2019-04-16',
#                '2019-05-10', '2019-05-15', '2019-06-11', '2019-06-20',
#                '2019-09-12', '2019-09-18'],
#               dtype='datetime64[ns]', name='date', length=303, freq=None)

# %% [markdown]
# # 当天开盘价比昨日收盘价跌-2%的日期汇总。

# %%
df['close'].shift(1)#先进行位移
# Out:
# date
# 2001-08-27         NaN
# 2001-08-28       5.554
# 2001-08-29       5.759
# 2001-08-30       5.684
# 2001-08-31       5.796
#                 ...
# 2020-01-17    1107.000
# 2020-01-20    1107.500
# 2020-01-21    1091.000
# 2020-01-22    1075.300
# 2020-01-23    1075.510
# Name: close, Length: 4394, dtype: float64

# %%
(df['open']-df['close'].shift(1))/df['close'].shift(1)<-0.02
# Out:
# date
# 2001-08-27    False
# 2001-08-28    False
# 2001-08-29    False
# 2001-08-30    False
# 2001-08-31    False
#               ...
# 2020-01-17    False
# 2020-01-20    False
# 2020-01-21    False
# 2020-01-22    False
# 2020-01-23    False
# Length: 4394, dtype: bool

# %%
df.loc[(df['open']-df['close'].shift(1))/df['close'].shift(1)<-0.02].index
# Out:
# DatetimeIndex(['2001-09-12', '2002-06-26', '2002-12-13', '2004-07-01',
#                '2004-10-29', '2006-08-21', '2006-08-23', '2007-01-25',
#                '2007-02-01', '2007-02-06', '2007-03-19', '2007-05-21',
#                '2007-05-30', '2007-06-05', '2007-07-27', '2007-09-05',
#                '2007-09-10', '2008-03-13', '2008-03-17', '2008-03-25',
#                '2008-03-27', '2008-04-22', '2008-04-23', '2008-04-29',
#                '2008-05-13', '2008-06-10', '2008-06-13', '2008-06-24',
#                '2008-06-27', '2008-08-11', '2008-08-19', '2008-09-23',
#                '2008-10-10', '2008-10-15', '2008-10-16', '2008-10-20',
#                '2008-10-23', '2008-10-27', '2008-11-06', '2008-11-12',
#                '2008-11-20', '2008-11-21', '2008-12-02', '2009-02-27',
#                '2009-03-25', '2009-08-13', '2010-04-26', '2010-04-30',
#                '2011-08-05', '2012-03-27', '2012-08-10', '2012-11-22',
# ...

# %%
data=df['2010':'2020']#2010到今天为止的交易日
data
# Out:
#                 open     close      high       low    volume    code
# date
# 2010-01-04   109.760   108.446   109.760   108.044  44304.88  600519
# 2010-01-05   109.116   108.127   109.441   107.846  31513.18  600519
# 2010-01-06   107.840   106.417   108.165   106.129  39889.03  600519
# 2010-01-07   106.417   104.477   106.691   103.302  48825.55  600519
# 2010-01-08   104.655   103.379   104.655   102.167  36702.09  600519
# ...              ...       ...       ...       ...       ...     ...
# 2020-01-17  1110.000  1107.500  1112.780  1101.010  23472.00  600519
# 2020-01-20  1111.860  1091.000  1111.860  1082.000  35391.00  600519
# 2020-01-21  1081.000  1075.300  1087.000  1072.300  32874.00  600519
# 2020-01-22  1070.000  1075.510  1084.000  1055.380  36200.00  600519
# 2020-01-23  1076.000  1052.800  1076.000  1037.000  53468.00  600519
#
# [2441 rows x 6 columns]

# %%
data1=data.resample('M').first()
data1
# Out:
#                 open     close      high       low     volume    code
# date
# 2010-01-31   109.760   108.446   109.760   108.044   44304.88  600519
# 2010-02-28   107.769   107.776   108.216   106.576   29655.94  600519
# 2010-03-31   106.219   106.085   106.857   105.925   21734.74  600519
# 2010-04-30   101.324   102.141   102.422   101.311   23980.83  600519
# 2010-05-31    81.676    82.091    82.678    80.974   23975.16  600519
# ...              ...       ...       ...       ...        ...     ...
# 2019-09-30  1139.990  1138.760  1144.980  1129.000   28234.00  600519
# 2019-10-31  1153.000  1167.100  1180.000  1152.010   31045.00  600519
# 2019-11-30  1181.000  1185.000  1191.950  1172.500   22811.00  600519
# 2019-12-31  1118.200  1133.000  1140.020  1118.200   30784.00  600519
# 2020-01-31  1128.000  1130.000  1145.060  1116.000  148099.00  600519
#
# [121 rows x 6 columns]

# %%
(data1['open']*100).sum() #每个月月初买入的所有股票价值2010年开始
# Out:
# 3911706.0999999996

# %%
data2=data.resample('A').last()[:-1]#因为已经过完年了到2020了不需要做切片排除2019 做切片排除就是后面加【：-1】
(data2['open']*1200).sum()
# Out:
# 4368184.8

# %%
data2
# Out:
#                 open     close      high       low   volume    code
# date
# 2010-12-31   117.103   118.469   118.701   116.620  46084.0  600519
# 2011-12-31   138.039   138.468   139.600   136.105  29460.0  600519
# 2012-12-31   155.208   152.087   156.292   150.144  51914.0  600519
# 2013-12-31    93.188    96.480    97.179    92.061  57546.0  600519
# 2014-12-31   157.642   161.056   161.379   157.132  46269.0  600519
# 2015-12-31   207.487   207.458   208.704   207.106  19673.0  600519
# 2016-12-31   317.239   324.563   325.670   317.239  34687.0  600519
# 2017-12-31   707.948   687.725   716.329   681.918  76038.0  600519
# 2018-12-31   563.300   590.010   596.400   560.000  63678.0  600519
# 2019-12-31  1183.000  1183.000  1188.000  1176.510  22588.0  600519

# %%
data3=data['close'][-1]*100

# %%
data['close'][-1]*100+(data2['open']*1200).sum()-(data1['open']*100).sum()#收入价值-成本的价值就是利润多少钱
# Out:
# 561758.7000000002

# %%
mf=ts.get_k_data('601318',start='1988-01-01')
mf
# Out:
#             date    open   close    high     low      volume    code
# 0     2007-03-01  21.254  19.890  21.666  19.469  1977633.51  601318
# 1     2007-03-02  19.979  19.728  20.166  19.503   425048.32  601318
# 2     2007-03-05  19.545  18.865  19.626  18.504   419196.74  601318
# 3     2007-03-06  18.704  19.235  19.554  18.597   297727.88  601318
# 4     2007-03-07  19.252  19.758  19.936  19.090   287463.78  601318
# ...          ...     ...     ...     ...     ...         ...     ...
# 3071  2020-01-17  86.150  86.250  86.900  85.850   555370.00  601318
# 3072  2020-01-20  88.300  87.600  88.700  87.350   936050.00  601318
# 3073  2020-01-21  87.000  85.600  87.290  85.600   727579.00  601318
# 3074  2020-01-22  85.000  85.220  85.480  83.830   736576.00  601318
# 3075  2020-01-23  84.010  83.490  84.560  82.480  1080020.00  601318
#
# [3076 rows x 7 columns]

# %%
s=mf['close']
mf['ma5']=s.rolling(5).mean()
mf['ma30']=s.rolling(30).mean()
mf
# Out:
#             date    open   close    high     low      volume    code      ma5  \
# 0     2007-03-01  21.254  19.890  21.666  19.469  1977633.51  601318      NaN
# 1     2007-03-02  19.979  19.728  20.166  19.503   425048.32  601318      NaN
# 2     2007-03-05  19.545  18.865  19.626  18.504   419196.74  601318      NaN
# 3     2007-03-06  18.704  19.235  19.554  18.597   297727.88  601318      NaN
# 4     2007-03-07  19.252  19.758  19.936  19.090   287463.78  601318  19.4952
# ...          ...     ...     ...     ...     ...         ...     ...      ...
# 3071  2020-01-17  86.150  86.250  86.900  85.850   555370.00  601318  86.1780
# 3072  2020-01-20  88.300  87.600  88.700  87.350   936050.00  601318  86.4080
# 3073  2020-01-21  87.000  85.600  87.290  85.600   727579.00  601318  86.1620
# 3074  2020-01-22  85.000  85.220  85.480  83.830   736576.00  601318  86.0440
# 3075  2020-01-23  84.010  83.490  84.560  82.480  1080020.00  601318  85.6320
#
#            ma30
# ...

# %%
mf1=mf[:100]

# %%
plt.plot(mf1['date'],mf1['ma5'],c='red')
plt.plot(mf1['date'],mf1['ma30'],c='blue')
